# %%
from Management import DataManagement
from simulation import run_simulation_updated

# %%
iterations = 50 #placeholder
filename = 'test3' #placeholder file name

#generate N simulations
sim = run_simulation_updated.generate_simulation_results(iterations,filename)
sim
# Out:
# 100%|████████████████████████████████████████| 50/50 [00:00<00:00, 51807.11it/s]
# Results saved to ../data/test3.npy
# '../data/test3.npy'

# %%
#process npy file into binary
processed_sims_total = DataManagement.load_process_simulations(sim)

# %%
#format into win counts diciontary
variation1, variation2 = DataManagement.analyze_all_combinations(processed_sims_total)

# %%
variation1
# Out:
#    Sequence 1 Sequence 2  Player 1 Wins  Player 2 Wins  Player 1 Win %  \
# 0         000        001             20             30            40.0
# 1         000        010             18             30            36.0
# 2         000        011              3             46             6.0
# 3         000        100              0             50             0.0
# 4         000        101             14             35            28.0
# 5         000        110              1             49             2.0
# 6         000        111             28             22            56.0
# 7         001        000             30             20            60.0
# 8         001        010             45              5            90.0
# 9         001        011             46              2            92.0
# 10        001        100              0             50             0.0
# 11        001        101             42              7            84.0
# ...

# %%
variation2
# Out:
#    Sequence 1 Sequence 2  Player 1 Wins  Player 2 Wins  Player 1 Win %  \
# 0         000        001             12             27            24.0
# 1         000        010             19             29            38.0
# 2         000        011             11             30            22.0
# 3         000        100             13             29            26.0
# 4         000        101             22             23            44.0
# 5         000        110             10             32            20.0
# 6         000        111             25             17            50.0
# 7         001        000             27             12            54.0
# 8         001        010             25             20            50.0
# 9         001        011             21             25            42.0
# 10        001        100              9             12            18.0
# 11        001        101             22             22            44.0
# ...
