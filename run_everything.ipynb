# %%
from Data_Management import DataManagement
import run_simulation
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 from Data_Management import DataManagement
#       2 import run_simulation
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'Data_Management'

# %%
iterations = 50 #placeholder
filename = 'test3' #placeholder file name

sim = run_simulation.generate_simulation_results(iterations,filename)
sim

# %%
processed_sims_total = DataManagement.load_process_simulations(sim)

# %%
output = DataManagement.analyze_all_combinations(processed_sims_total)
output
# Out:
# (   Sequence 1 Sequence 2  Player 1 Wins  Player 2 Wins  Player 1 Win %  \
#  0         000        001             20             30            40.0
#  1         000        010             18             30            36.0
#  2         000        011              3             46             6.0
#  3         000        100              0             50             0.0
#  4         000        101             14             35            28.0
#  5         000        110              1             49             2.0
#  6         000        111             28             22            56.0
#  7         001        000             30             20            60.0
#  8         001        010             45              5            90.0
#  9         001        011             46              2            92.0
#  10        001        100              0             50             0.0
#  11        001        101             42              7            84.0
# ...
