# %% [markdown]
# # Run everything

# %%
import penney
import importlib
importlib.reload(penney)
# Out:
# <module 'penney' from '/home/carlo/Documents/GitHub/penney-game/penney.py'>

# %%
penney.add_new_sims(iterations=100, output_filename='testing', seed=123)
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 127875.12it/s]
# Shuffled decks saved to data/testing.npy
# Processing Pairs: 100%|██████████| 56/56 [00:00<00:00, 186.64it/s]
# <> Variation1.png saved <>
# <> Variation2.png saved <>
