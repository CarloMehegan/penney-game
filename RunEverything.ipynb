# %% [markdown]
# ### Things that need to be done
# * combine_past_data/update_dataframe: we need a function that will
# *

# %%
from Management import DataManagement
from Simulation import RunSimulation
from Visualization import DataVisualization
import numpy as np
import importlib
importlib.reload(DataManagement)
importlib.reload(RunSimulation)
importlib.reload(DataVisualization)
# Out:
# <module 'Visualization.DataVisualization' from '/home/carlo/Documents/GitHub/penney-game/Visualization/DataVisualization.py'>

# %%
iterations = 1000
filename = 'test3'

sim = RunSimulation.generate_simulation_results(iterations,filename,seed=12222,path='data')
sim
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 94653.91it/s]
# Shuffled decks saved to data/test3.npy
# 'data/test3.npy'

# %%
#must be changed to not be hardcoded
processed_sims_total = DataManagement.load_process_simulations(sim)

# %%
Variation1, Variation2 = DataManagement.analyze_all_combinations(processed_sims_total)
# Out:
# Processing Pairs: 100%|██████████| 56/56 [00:02<00:00, 22.13it/s]

# %%
#having issues with this one, why does v1_combined have more rows than Variation1
v1_combined, v2_combined = DataManagement.combine_past_data(Variation1, Variation2, 'variation1.csv', 'variation2.csv', folder='data')

# %%
v1_combined.head()
# Out:
#   Sequence 1 Sequence 2  Player 1 Wins  Player 2 Wins  Player 1 Win %
# 0        000        001           1059           1095           49.16
# 1        000        010            656           1483           30.67
# 2        000        011            470           1663           22.03
# 3        000        100              0           2200            0.00
# 4        000        101            633           1499           29.69

# %%
Variation1.head()
# Out:
#   Sequence 1 Sequence 2  Player 1 Wins  Player 2 Wins  Player 1 Win %
# 0        000        001            476            504           48.57
# 1        000        010            309            667           31.66
# 2        000        011            217            752           22.39
# 3        000        100              0           1000            0.00
# 4        000        101            293            669           30.46

# %%
visualization1 = DataVisualization.generate_heatmap(v1_combined, 'Variation1')
visualization2 = DataVisualization.generate_heatmap(v2_combined, 'Variation2')
# Out:
# <> Variation1.png saved <>
# <> Variation2.png saved <>

# %%
v1_combined
# Out:
#    Sequence 1 Sequence 2  Player 1 Wins  Player 2 Wins  Player 1 Win %
# 0         000        001         474914         500562           48.69
# 1         000        010         293845         685554           30.00
# 2         000        011         203513         767623           20.96
# 3         000        100              3         999994            0.00
# 4         000        101         278220         692821           28.65
# 5         000        110          17486         976840            1.76
# 6         000        111         484094         484389           49.98
# 7         001        000         500562         474914           51.31
# 8         001        010         851287         130027           86.75
# 9         001        011         952212          35683           96.39
# 10        001        100            901         998732            0.09
# 11        001        101         935085          46620           95.25
# 12        001        110         466349         466355           50.00
# 13        001        111         976721          17473           98.24
# 14        010        000         685554         293845           70.00
# 15        010        001         130027         851287           13.25
# 16        010        011         477528         479487           49.90
# 17        010        100         397599         573774           40.93
# 18        010        101         483682         487294           49.81
# 19        010        110          46174         935791            4.70
# 20        010        111         691319         279626           71.20
# 21        011        000         767623         203513           79.04
# 22        011        001          35683         952212            3.61
# 23        011        010         479487         477528           50.10
# 24        011        100         478315         478650           49.98
# 25        011        101         575137         396155           59.21
# 26        011        110         998771            900           99.91
# 27        011        111         999996              2          100.00
# 28        100        000         999994              3          100.00
# 29        100        001         998732            901           99.91
# 30        100        010         573774         397599           59.07
# 31        100        011         478650         478315           50.02
# 32        100        101         477855         478919           49.94
# 33        100        110          35242         952478            3.57
# 34        100        111         768353         202697           79.13
# 35        101        000         692821         278220           71.35
# 36        101        001          46620         935085            4.75
# 37        101        010         487294         483682           50.19
# 38        101        011         396155         575137           40.79
# 39        101        100         478919         477855           50.06
# 40        101        110         128913         852581           13.13
# 41        101        111         684995         294311           69.95
# 42        110        000         976840          17486           98.24
# 43        110        001         466355         466349           50.00
# 44        110        010         935791          46174           95.30
# 45        110        011            900         998771            0.09
# 46        110        100         952478          35242           96.43
# 47        110        101         852581         128913           86.87
# 48        110        111         501157         474607           51.36
# 49        111        000         484389         484094           50.02
# 50        111        001          17473         976721            1.76
# 51        111        010         279626         691319           28.80
# 52        111        011              2         999996            0.00
# 53        111        100         202697         768353           20.87
# 54        111        101         294311         684995           30.05
# 55        111        110         474607         501157           48.64
