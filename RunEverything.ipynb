# %% [markdown]
# # Run everything

# %%
import penney
import importlib
importlib.reload(penney)
# Out:
# <module 'penney' from '/home/carlo/Documents/GitHub/penney-game/penney.py'>

# %%
penney.add_new_sims(iterations=1000, output_filename='test3', seed=123)
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 60871.71it/s]
# Shuffled decks saved to data/test3.npy
# Processing Pairs: 100%|██████████| 56/56 [00:02<00:00, 21.24it/s]
# <> figures/Variation1.png saved <>
# <> figures/Variation2.png saved <>
