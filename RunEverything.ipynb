# %% [markdown]
# # Run everything

# %%
import penney
import importlib
importlib.reload(penney)
# Out:
# <module 'penney' from '/home/carlo/Documents/GitHub/penney-game/penney.py'>

# %%
penney.add_new_sims(iterations=10000, output_filename='test3', seed=123)
# Out:
# 100%|██████████| 10000/10000 [00:00<00:00, 95473.29it/s]
# Shuffled decks saved to data/test3.npy
# Processing Pairs: 100%|██████████| 56/56 [00:21<00:00,  2.56it/s]
# <> Variation1.png saved <>
# <> Variation2.png saved <>
