# %%
from DataViz import DataViz

# %%
generator = DataViz()

# %%
generator.generate_heatmap('Variation1.csv', title='Variation 1', filename='testvar1.png')
generator.generate_heatmap('Variation2.csv', title='Variation 2', filename='testvar2.png')
# Out:
# <> testvar1.png saved <>
# <> testvar2.png saved <>
